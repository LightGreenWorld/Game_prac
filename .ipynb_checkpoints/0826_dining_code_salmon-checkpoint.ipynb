# %%
import os
import numpy as np
import pandas as pd
# from selenium.webdriver.common.action_chains import ActionChains
# from selenium.webdriver.common.keys import Keys
from selenium import webdriver
# from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup

# import time
# import urllib
# import requests
# import re

# %%
driver=webdriver.Chrome('chromedriver.exe')
# action=ActionChains(driver)

# %%
driver.get('https://www.diningcode.com/list.php?query=%EA%B5%AD%EB%B0%A5%20%EB%A7%9B%EC%A7%91')
driver.maximize_window()
#driver.implicitly_wait(3)
#driver.find_element_by_css_selector('body > main > article > section > div > a').click()

# %%
#더보기버튼 안나올때까지 클릭
while True:
    try:
        더보기 = driver.find_element_by_xpath('//*[@id="div_list_more"]')
        더보기.click()
        time.sleep(2)
    except:
        break

# %%
rlink = []
while True:
    try:
        m = driver.find_element_by_css_selector('#div_list_more')
        m.click()
        time.sleep(1)
    except:
        break

#태그별로 url뽑아오기
html_doc = driver.page_source
soup = BeautifulSoup(html_doc, 'html.parser')
for link in soup.find_all('a'):
    if 'profile' in link.get('href'):
        rlink.append('https://www.diningcode.com/' + link.get('href'))
    
links = rlink
print(links)
len(links)
# Out:
# ['https://www.diningcode.com//profile.php?rid=qDqIccpAUNVy', 'https://www.diningcode.com//profile.php?rid=PYk33Cv6jpwY', 'https://www.diningcode.com//profile.php?rid=7hVyqU2qXf1W', 'https://www.diningcode.com//profile.php?rid=jAL2mG45kQKq', 'https://www.diningcode.com//profile.php?rid=yJWYroWneBZz', 'https://www.diningcode.com//profile.php?rid=rgsTWoDK2FRO', 'https://www.diningcode.com//profile.php?rid=wZ0eHYiox0r7', 'https://www.diningcode.com//profile.php?rid=JoJejHek5u8P', 'https://www.diningcode.com//profile.php?rid=5xX9qiAjOoKu', 'https://www.diningcode.com//profile.php?rid=UvhFuVUiB5mH', 'https://www.diningcode.com//profile.php?rid=HSw0PeQwGAI4', 'https://www.diningcode.com//profile.php?rid=W8QohJNero93', 'https://www.diningcode.com//profile.php?rid=pdVGcp9QJ5Ms', 'https://www.diningcode.com//profile.php?rid=Wphn9urf9Crj', 'https://www.diningcode.com//profile.php?rid=xo80uBfS9kKu', 'https://www.diningcode.com//profile.php?rid=b3DDsiDJxXYE', 'https://www.diningcode.com//profile.php?rid=njPwkrsv7oFr', 'https://www.diningcode.com//profile.php?rid=4fgdW6Inktww', 'https://www.diningcode.com//profile.php?rid=TbHBvvTWVSIo', 'https://www.diningcode.com//profile.php?rid=1246iEICOgZS', 'https://www.diningcode.com//profile.php?rid=S3xWF4cDCXZ3', 'https://www.diningcode.com//profile.php?rid=X4j61Xt53DOZ', 'https://www.diningcode.com//profile.php?rid=6giP1BV3d8KD', 'https://www.diningcode.com//profile.php?rid=hc8tKwPbSxEp', 'https://www.diningcode.com//profile.php?rid=y1YCSnBe9TWq', 'https://www.diningcode.com//profile.php?rid=KXXmbQrhHrOA', 'https://www.diningcode.com//profile.php?rid=trbVz72n3j6b', 'https://www.diningcode.com//profile.php?rid=a8MWVde7X9rS', 'https://www.diningcode.com//profile.php?rid=QM1TLH0Fb2zV', 'https://www.diningcode.com//profile.php?rid=Q2gu84vBJ8kJ', 'https://www.diningcode.com//profile.php?rid=Ak8MrOwtTveG', 'https://www.diningcode.com//profile.php?rid=BUogm42iracN', 'https://www.diningcode.com//profile.php?rid=VlnDXZvykX7J', 'https://www.diningcode.com//profile.php?rid=g8ba1qfClKl2', 'https://www.diningcode.com//profile.php?rid=3Ez3Scfw3nqI', 'https://www.diningcode.com//profile.php?rid=hBLa5NEhfnUT', 'https://www.diningcode.com//profile.php?rid=bc2ApCmKHvoL', 'https://www.diningcode.com//profile.php?rid=IpYrb67DLmdA', 'https://www.diningcode.com//profile.php?rid=u9rXLLu8Nfg5', 'https://www.diningcode.com//profile.php?rid=aIUYRYkX4Dxl', 'https://www.diningcode.com//profile.php?rid=hTuzMLnle71P', 'https://www.diningcode.com//profile.php?rid=dUCVzDEFuKSu', 'https://www.diningcode.com//profile.php?rid=w3Xd6M6YGXPP', 'https://www.diningcode.com//profile.php?rid=l0id7CmcvjwY', 'https://www.diningcode.com//profile.php?rid=Y0VHi4X4851U', 'https://www.diningcode.com//profile.php?rid=P16GK4qSC2VZ', 'https://www.diningcode.com//profile.php?rid=9ZZJikWXBt2p', 'https://www.diningcode.com//profile.php?rid=E55qlHIVVscR', 'https://www.diningcode.com//profile.php?rid=mfnxiMVtuuWL', 'https://www.diningcode.com//profile.php?rid=oLD46dibkVNd', 'https://www.diningcode.com//profile.php?rid=upBDWRRobFiO', 'https://www.diningcode.com//profile.php?rid=oFt7VQgJPD1x', 'https://www.diningcode.com//profile.php?rid=YmCF1bGp9TCd', 'https://www.diningcode.com//profile.php?rid=qpxxC2UiEFYc', 'https://www.diningcode.com//profile.php?rid=hNZpGtnqXxcM', 'https://www.diningcode.com//profile.php?rid=AQfszZfqmkxz', 'https://www.diningcode.com//profile.php?rid=hbzPdcZLtAN8', 'https://www.diningcode.com//profile.php?rid=rLGXhPfOnPdg', 'https://www.diningcode.com//profile.php?rid=qJY5ve0P0qno', 'https://www.diningcode.com//profile.php?rid=kx7bxsyjC9Ew', 'https://www.diningcode.com//profile.php?rid=VHTQmUiX7fVa', 'https://www.diningcode.com//profile.php?rid=gsxaiq6TY1Nl', 'https://www.diningcode.com//profile.php?rid=hUlg0DIa05Kq', 'https://www.diningcode.com//profile.php?rid=nQcNfpl8SFwl', 'https://www.diningcode.com//profile.php?rid=KhCvIeW4YVI7', 'https://www.diningcode.com//profile.php?rid=RmE10nZ0MLmo', 'https://www.diningcode.com//profile.ph ...
# 100

# %%
np.savetxt('dining_code_url(2).txt', links,fmt='%s')

# %%
f = open('./dining_code_url(2).txt', 'r')
df = f

# %%
result=pd.DataFrame({
    '맛집url':df
})

# %%
# result

# %%
result_list = result['맛집url'].to_list()
len(result_list)
# Out:
# 100

# %%
result=np.array(result['맛집url'].tolist())
len(result)
# Out:
# 100

# %%
test = pd.DataFrame(columns=['맛집', '평점','주소','번호','영업시간','메뉴정보','리뷰'])
test
# Out:
# Empty DataFrame
# Columns: [맛집, 평점, 주소, 번호, 영업시간, 메뉴정보, 리뷰]
# Index: []

# %%
for final in range(len(result_list)):
    driver=webdriver.Chrome('chromedriver.exe')
    driver.get(result_list[final])
    #html_doc = driver.page_source
    #soup = BeautifulSoup(html_doc, 'html.parser')
    #맛집 이름
    try:    
        title = driver.find_element_by_xpath('//*[@id="div_profile"]/div[1]/div[2]/p').text
    except:
        title = None
        
    #맛집 평점
    try:
        count = driver.find_element_by_xpath('//*[@id="lbl_review_point"]').text.replace('\n', '')
    except:
        count = None
    # info = soup.find("tbody").get_text().replace('\n', '')
    # print(info)
    # 맛집 주소
    
    try:
        address = driver.find_element_by_xpath('//*[@id="div_profile"]/div[2]/ul/li[1]').text
    except:
        address = None
        
    # 전화 번호
    try:
        number = driver.find_element_by_xpath('//*[@id="div_profile"]/div[2]/ul/li[2]').text
    except:
        number = None
    # 영업 시간
    try:
        time = driver.find_element_by_xpath('//*[@id="div_detail"]/div[1]').text.replace('\n', '')
    except:
        time = None
    # 메뉴 정보
    try:
        info = driver.find_element_by_xpath('//*[@id="div_detail"]/div[2]').text
    except:
        info = None
    
    try:
        menu = info.replace('메뉴정보','').replace('더보기', '').replace('\n', '')
    except:
        menu = None
    # 리뷰 
    
    try:
        review = driver.find_element_by_xpath('//*[@id="div_profile"]/div[8]').text.replace('\n', '')
    except:
        review = None
    test.loc[final] = [title,count,address,number,time,menu,review]
    
    driver.close()

# %%
test

# %%
test.to_csv('국밥.csv', index=False, encoding='utf-8-sig')
